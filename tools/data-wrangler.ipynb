# %% [markdown]
# # Code to migrate the data files in the archive to JSON
#
# We want all the data in a modern format.
#
# # WWII Data
#
# - allied.xml - list of allied planes
# - axis.xml - lise of axis planes
# - holtgrewe.xml - This is the primary data file.
# - index.xml - Looks like some kind of mapping file???

# %% [markdown]
# # Holtgrewe Models
#
# The main location for data (in the WWII collection) is holtgrewe.xml.  It
# consists of a series of <model> tags.  Here is an example:
#
# ```xml
# <model index="1" holtgrewe="001" affiliation="1" cos="Great Britain" com="Great Britain" logo="grb">
#   <img name="001"></img>
#   <title><![CDATA[Miles M.9A Master Mk I]]></title>
#   <type type="Advanced Trainer"></type>
#   <firstYR>1941</firstYR>
#   <displayedAs>
#     <![CDATA[This model represents an aircraft of the Royal Air Force No. ...]]>
#   </displayedAs>
#   <history>
#     <![CDATA[As monoplane fighters began to equip Royal Air Force units, ...]]>
#   </history>
#   <tech>
#     <powerplant>
#       <![CDATA[One Rolls-Royce Kestrel XXX, liquid-cooled inline piston engine of 715 hp (533 kW)]]>
#     </powerplant>
#     <performance>
#       <maxspeed>226 mph at 15,000 feet (364 km/h at 4,570 m)</maxspeed>
#       <ceiling>28,000 feet (8,500 m)</ceiling>
#       <range>500 miles (805 km)</range>
#     </performance>
#     <weight>4,160 pounds (1,886 kg)</weight>
#     <maxweight>5,352 pounds (2,428 kg)</maxweight>
#     <dimensions span="38 feet 10 inches (11.85 m)" lengths="30 feet 5 inches (9.27 m)" height="9 feet 3 inches (2.82 m)">
#     </dimensions>
#     <armament><![CDATA[Provisions for one fixed, forward-firing Vickers 0.303 i...]]></armament>
#     <crew num="2 [one student, one instructor]"></crew>
#     <comments>
#       <![CDATA[Model Builder's Comments: This Master has the typical... "]]>
#     </comments>
#   </tech>
# </model>
# ```
#
# We desired to convert these models into JSON format for use in a web application.
# This could be encoded as follows (editing some fields for clarity):
#
# ```json
# {
#   modelNumber: "001",
#   countryOfService: "Great Britain",
#   countryOfManufacture: "Great Britain",
#   logo: "grb",
#   title: "Miles M.9A Master Mk I",
#   type: "Advanced Trainer",
#   firstYear: 1941,
#   displayedAs: "This model represents an aircraft of the Royal Air Force No. ... ",
#   history: "As monoplane fighters began to equip Royal Air Force units, ...",
#   tech: {
#     powerplant: "One Rolls-Royce Kestrel XXX, liquid-cooled inline piston engine of 715 hp (533 kW)",
#     performance: {
#       maxSpeed: "226 mph at 15,000 feet (364 km/h at 4,570 m)",
#       ceiling: "28,000 feet (8,500 m)"
#       range: "500 miles (805 km)"
#     },
#     weight: "4,160 pounds (1,886 kg)",
#     maxWeight: "5,352 pounds (2,428 kg)",
#     dimensions: {
#       span: "38 feet 10 inches (11.85 m)",
#       length: "30 feet 5 inches (9.27 m)",
#       height: "9 feet 3 inches (2.82 m)"
#     }
#     armament: "Provisions for one fixed, forward-firing Vickers 0.303 i... ",
#     crewSize: "2 [one student, one instructor]",
#     comments: "Model Builder's Comments: This Master has the typical... "
#   }
# }
# ```
#
# We could make this data more generally useful, by removing formatting from
# data fields, allowing the display software to convert units in a standard
# way.  As it appears that the standard units are English, I would adopt that
# for data values (feet (decimal), miles, pounds, mph).  This would further
# convert this model to:
#
# ```json
# {
#   modelNumber: "001",
#   countryOfService: "Great Britain",
#   countryOfManufacture: "Great Britain",
#   logo: "grb",
#   title: "Miles M.9A Master Mk I",
#   type: "Advanced Trainer",
#   firstYear: 1941,
#   displayedAs: "This model represents an aircraft of the Royal Air Force No. ... ",
#   history: "As monoplane fighters began to equip Royal Air Force units, ...",
#   tech: {
#     powerplant: {
#       engines: 1,
#       hp: 715,
#       description: "Rolls-Royce Kestrel XXX, liquid-cooled inline piston engine",
#     },
#     performance: {
#       maxSpeed: {
#         speed: 226,
#         altitude: 15000
#        }
#       ceiling: 28000,
#       range: 500,
#     },
#     weight: 4160,
#     maxWeight: 5352,
#     dimensions: {
#       span: 38.83,
#       length: 30.42,
#       height: 9.25,
#     }
#     armament: "Provisions for one fixed, forward-firing Vickers 0.303 i... ",
#     crew: {
#       size: 2,
#       makeup: "one student, one instructor"
#     }
#   },
#   comments: "Model Builder's Comments: This Master has the typical... "
# }
# ```

# %%
# !ls -al ../archive/wwii/data
# Out:
# total 1156
# drwxrwxr-x 2 mckoss mckoss    4096 Jan 26 16:00 .
# drwxrwxr-x 4 mckoss mckoss    4096 Jan 26 17:18 ..
# -rw-rw-r-- 1 mckoss mckoss   14879 Jan 26 15:59 allied.xml
# -rw-rw-r-- 1 mckoss mckoss   13466 Jan 26 15:59 axis.xml
# -rw-rw-r-- 1 mckoss mckoss 1133333 Jan 26 15:59 holtgrewe.xml
# -rw-rw-r-- 1 mckoss mckoss    6213 Jan 26 15:59 index.xml

# %%
# !pip install xmltodict

# %%
DATA_DIR = '../archive/wwii/data'

# %%
import json
import xmltodict

with open(f"{DATA_DIR}/holtgrewe.xml", 'r') as f:
    data = f.readlines()

# Parser needs a single top-level element - so we'll wrap the data in a root element
data.insert(1, '<root>\n')
data.append('</root>\n')

models = xmltodict.parse(''.join(data))['root']['model']
print(json.dumps(models[0], indent=2))
# Out:
# {
#   "@index": "1",
#   "@holtgrewe": "001",
#   "@affiliation": "1",
#   "@cos": "Great Britain",
#   "@com": "Great Britain",
#   "@logo": "grb",
#   "img": {
#     "@name": "001"
#   },
#   "title": "Miles M.9A Master Mk I",
#   "type": {
#     "@type": "Advanced Trainer"
#   },
#   "firstYR": "1941",
#   "displayedAs": "This model represents an aircraft of the Royal Air Force No. 8 Flying Training School, Ternhill, England, April 1940.",
#   "history": "As monoplane fighters began to equip Royal Air Force units, it became obvious that an advanced trainer was needed to transition new young pilots from their basic elementary trainers to the high performance fighters they would be flying. To fulfill this need, the Air Ministry issued a specification for a high performance trainer. George Miles designed the \"Master\" in response. The new trainer was of smooth aeronautical design and was built of wood. Miles' first prototype, which first flew on June 3, 1937, was rejected by the Air Ministry, but Miles continued on with the project as a private venture. With the need for an advanced trainer becoming ever more pressing, the Royal Air Force finally placed an order in June of 1938 for the Master aircraft, which amounted to over 2 million pounds\u2014the largest order in RAF history for a trainer. The flight characteristics of the new trainer, which came into RAF service just prior to the beginning of World War II, were quite similar to the Hawker Hurricane and the Supermarine Spitfire [both modeled elsewhere in this collection], which were the RAF fighters of that period. All variants of the Master had an instructors' seat in the rear of the cockpit that could be raised so the instructor could look over the head of his student during flight. The machine proved to be excellent in its intended role and its performance was so outstanding that during the dark days following the fall of France when Britain was desperate for fighter aircraft, 24 Masters were modified into single seat fighters with six 0.303 inch machine guns for emergency use. However, none of these were ever used in this role. The model shows the original wing configuration. All variants had the wings clipped in 1942 to reduce stress and improve maneuverability. Including all variants, a total of over 3,200 were manufactured during World War II for use by the Royal Air Force and by Commonwealth Air Forces.",
#   "tech": {
#     "powerplant": "One Rolls-Royce Kestrel XXX, liquid-cooled inline piston engine of 715 hp (533 kW)",
#     "performance": {
#       "maxspeed": "226 mph at 15,000 feet (364 km/h at 4,570 m)",
#       "ceiling": "28,000 feet (8,500 m)",
#       "range": "500 miles (805 km)"
#     },
#     "weight": "4,160 pounds (1,886 kg)",
#     "maxweight": "5,352 pounds (2,428 kg)",
#     "dimensions": {
#       "@span": "38 feet 10 inches (11.85 m)",
#       "@lengths": "30 feet 5 inches (9.27 m)",
#       "@height": "9 feet 3 inches (2.82 m)"
#     },
#     "armament": "Provisions for one fixed, forward-firing Vickers 0.303 inches (7.7 mm) machine gun and eight practice bombs",
#     "crew": {
#       "@num": "2 [one student, one instructor]"
#     },
#     "comments": "Model Builder's Comments: This Master has the typical RAF trainer paint scheme of earth brown and forest green on upper surfaces and yellow-orange on under surfaces\u2014the latter for easy identification to avoid \"friendly fire.\""
#   }
# }

# %%
import re

current_model = None
errors = []

def reshape_model(m):
  return {
    'modelNumber': parse_model(m['@holtgrewe']),
    'countryOfService': m['@cos'],
    'countryOfManufacture': m['@com'],
    'logo': m['@logo'],
    'title': m['title'],
    'type': m['type']['@type'],
    'firstYear': m['firstYR'],
    'displayedAs': m['displayedAs'],
    'history': m['history'],
    'tech': {
      'powerplant': parse_powerplant(m['tech']['powerplant']),
      'performance': {
        'maxSpeed': parse_speed(m['tech']['performance']['maxspeed']),
        'ceiling': parse_ceiling(m['tech']['performance']['ceiling']),
        'range': parse_range(m['tech']['performance']['range']),
      },
      'weight': parse_weight(m['tech']['weight']),
      'maxWeight': parse_weight(m['tech']['maxweight']),
      'dimensions': {
        'span': parse_dimension(m['tech']['dimensions']['@span']),
        'length': parse_dimension(m['tech']['dimensions']['@lengths']),
        'height': parse_dimension(m['tech']['dimensions']['@height']),
      },
      'armament': m['tech']['armament'],
      'crew': parse_crew(m['tech']['crew']['@num']),
    },
    'comments': m['tech']['comments'],
  }

def parse_model(m):
  global current_model
  current_model = m
  return m

def parse_powerplant(d):
  engines = 1
  if re.match(r'One ', d):
    d = d[4:]
  elif re.match(r'Two ', d):
    d = d[4:]
    engines = 2

  result = {
    'engines': engines,
  }

  m = re.match(r'(.*) of ([\d,]+) hp (.*)', d)

  if m is None:
    error(f"Couldn't parse powerplant: {d}")
  else:
    result['hp'] = parse_int(m.group(2))
    d = m.group(1)

  result['description'] = d
  
  return result

def parse_speed(s):
  m = re.match(r'(\d+) mph at ([\d,]+) feet', s)
  if m is None:
    error(f"Couldn't parse speed: {s}")
    return None

  return {
    'speed': int(m.group(1)),
    'altitude': parse_int(m.group(2))
  }

def parse_ceiling(c):
  m = re.match(r'([\d,]+) feet', c)

  if m is None:
    error(f"Couldn't parse ceiling: {c}")
    return None

  return parse_int(m.group(1))

def parse_range(r):
  m = re.match(r'(\d+) miles', r)
  if m is None:
    error(f"Couldn't parse range: {r}")
    return None

  return parse_int(m.group(1))

def parse_weight(w):
  if w is None:
    error("Missing weight");
    return None

  m = re.match(r'([\d,]+) pounds', w)
  if m is None:
    error(f"Couldn't parse weight: {w}")
    return None

  return parse_int(m.group(1))

def parse_dimension(d):
  m = re.match(r'(\d+) feet ([\d]+) inches', d)
  if m is None:
    error(f"Couldn't parse dimension: {d}")
    return None

  ft = parse_int(m.group(1))
  inch = parse_int(m.group(2))

  return round(ft + inch/12, 2)

def parse_crew(c):
  m = re.match(r'(\d+|None|Two),? *(.*)?', c)
  if m is None:
    error(f"Couldn't parse crew: {c}")
    return None

  if m.group(1) == 'None':
    size = 0
  elif m.group(1) == 'Two':
    size = 2
  else:
    size = parse_int(m.group(1))

  result = {
    'size': size
  }

  if m.group(2) is not None and m.group(2) != '':
    m_d = re.match(r'\[(.+)\]', m.group(2))
    if m_d is not None:
      result['makeup'] = m_d.group(1)
    else:
      print(m.group(2))
      result['makeup'] = m.group(2)

  return result

def parse_int(s):
  return int(s.replace(',', ''))

def error(s):
  errors.append(f"{current_model}: {s}")


# Test code on a sample model

print(json.dumps(reshape_model(models[0]), indent=2))

if len(errors) > 0:
  error_lines = '\n'.join(errors)
  print(f"Errors:\n{error_lines}")
# Out:
# {
#   "modelNumber": "001",
#   "countryOfService": "Great Britain",
#   "countryOfManufacture": "Great Britain",
#   "logo": "grb",
#   "title": "Miles M.9A Master Mk I",
#   "type": "Advanced Trainer",
#   "firstYear": "1941",
#   "displayedAs": "This model represents an aircraft of the Royal Air Force No. 8 Flying Training School, Ternhill, England, April 1940.",
#   "history": "As monoplane fighters began to equip Royal Air Force units, it became obvious that an advanced trainer was needed to transition new young pilots from their basic elementary trainers to the high performance fighters they would be flying. To fulfill this need, the Air Ministry issued a specification for a high performance trainer. George Miles designed the \"Master\" in response. The new trainer was of smooth aeronautical design and was built of wood. Miles' first prototype, which first flew on June 3, 1937, was rejected by the Air Ministry, but Miles continued on with the project as a private venture. With the need for an advanced trainer becoming ever more pressing, the Royal Air Force finally placed an order in June of 1938 for the Master aircraft, which amounted to over 2 million pounds\u2014the largest order in RAF history for a trainer. The flight characteristics of the new trainer, which came into RAF service just prior to the beginning of World War II, were quite similar to the Hawker Hurricane and the Supermarine Spitfire [both modeled elsewhere in this collection], which were the RAF fighters of that period. All variants of the Master had an instructors' seat in the rear of the cockpit that could be raised so the instructor could look over the head of his student during flight. The machine proved to be excellent in its intended role and its performance was so outstanding that during the dark days following the fall of France when Britain was desperate for fighter aircraft, 24 Masters were modified into single seat fighters with six 0.303 inch machine guns for emergency use. However, none of these were ever used in this role. The model shows the original wing configuration. All variants had the wings clipped in 1942 to reduce stress and improve maneuverability. Including all variants, a total of over 3,200 were manufactured during World War II for use by the Royal Air Force and by Commonwealth Air Forces.",
#   "tech": {
#     "powerplant": {
#       "engines": 1,
#       "hp": 715,
#       "description": "Rolls-Royce Kestrel XXX, liquid-cooled inline piston engine"
#     },
#     "performance": {
#       "maxSpeed": {
#         "speed": 226,
#         "altitude": 15000
#       },
#       "ceiling": 28000,
#       "range": 500
#     },
#     "weight": 4160,
#     "maxWeight": 5352,
#     "dimensions": {
#       "span": 38.83,
#       "length": 30.42,
#       "height": 9.25
#     },
#     "armament": "Provisions for one fixed, forward-firing Vickers 0.303 inches (7.7 mm) machine gun and eight practice bombs",
#     "crew": {
#       "size": 2,
#       "makeup": "one student, one instructor"
#     }
#   },
#   "comments": "Model Builder's Comments: This Master has the typical RAF trainer paint scheme of earth brown and forest green on upper surfaces and yellow-orange on under surfaces\u2014the latter for easy identification to avoid \"friendly fire.\""
# }

# %%
for m in models:
  out = reshape_model(m)
  # print(json.dumps(out['tech']['crew'], indent=2))

print(f"Finished parsing with model '{current_model}'.  {len(errors)} errors.")
print('\n'.join((err for err in errors if 'crew' in err)))
print('\n'.join(errors))
# Out:
# or 3
# or 3
# or 5
# or 5
# to 6
# to 7, usually 7
# to 6 dependent upon training role
# plus 3 or 4 passengers
# with 3 passengers
# or 3
# or 7
# to 5
# to 6
# to 9
# to 7
# or 5 [excluding passengers]
# in fighter, none in converted bomber
# to 8
# or 3
# to 5 dependent upon training role
# or 5
# crew, seating for 8 passengers
# to 6
# or 8
# to 6
# to 5
# or 2
# to 6
# or 4
# or 3
# to 7 [dependent on function]
# or 5
# to 5
# or 6
# and up to 3 passengers
# or 4
# or 5
# pilots, maximum 25 troops
# to 5 [dependent upon training role]
# to 12
# to 9
# to 10
# or 7 [excluding passengers]
# to 5
# or 5
# to 8
# with up to 8 passengers
# to 6, including students
# or 7
# observer
# to 10
# or 2
# or 2 [4 to 6 passengers]
# to 6, dependent upon role
# if no bomb load, up to 24 fully equipped troops
# Finished parsing with model '426'.  486 errors.
# 305: Couldn't parse crew: Usually crew of 2 and up to 6 passengers
# 320: Couldn't parse crew: Flight crew of 5 or 6
# 004: Couldn't parse range: 1,055 miles (1,700 km)
# 007: Couldn't parse dimension: 27 feet 1 inch (8.27 m)
# 009: Couldn't parse range: 1,930 miles (3,105 km)
# 013: Couldn't parse powerplant: Junkers Jumo 004 B-1 turbo jet engines with a thrust of 1,986 pounds (8.8 kN) each
# 014: Couldn't parse powerplant: BMW 003 E-1, turbojet with 1,764 pounds (7.8 kN) of thrust
# 015: Couldn't parse dimension: 12 feet 1 inch (3.68 m)
# 017: Couldn't parse range: 1,013 miles (1,630 km)
# 018: Couldn't parse range: 2,600 miles (4,185 km)
# 019: Couldn't parse dimension: 35 feet 1 inch (10.68 m)
# 020: Couldn't parse powerplant: Walter HMK 509 A-2 rocket engine with a thrust of 3,750 pounds (16.7 kN)
# 020: Couldn't parse speed: 596 mph [Mach 0.8] at 32,810 feet (960 km/h at 12,100 m)
# 020: Couldn't parse dimension: 9 feet 1 inch (2.77 m)
# 024: Couldn't parse range: 1,299 miles (2,090 km) without drop tanks
# 027: Couldn't parse dimension: 29 feet 1 inch (8.85 m)
# 028: Couldn't parse range: 1,040 miles (1,675 km) on internal fuel
# 030: Couldn't parse dimension: 36 feet 1 inch (11.00 m)
# 031: Couldn't parse dimension: 37 feet 1 inch (11.30 m)
# 032: Couldn't parse range: 1,243 miles (2,000 km)
# 032: Couldn't parse dimension: 36 feet 1 inch (11.00 m)
# 032: Couldn't parse dimension: 12 feet 1 inch (3.68 m)
# 036: Couldn't parse powerplant: Rolls-Royce Derwent 1 turbojets with 2,000 pounds (8.9 kN) of thrust each
# 038: Couldn't parse range: 1,014 miles (1,632 km) without drop tanks
# 038: Couldn't parse dimension: 16 feet 1 inch (4.90 m)
# 040: Couldn't parse dimension: 12 feet 1 inch (3.68 m)
# 041: Couldn't parse dimension: 16 feet 1 inch (4.90 m)
# 045: Couldn't parse dimension: 8 feet 1 inch (2.60 m)
# 048: Couldn't parse powerplant: Argus 109 014 Pulse jet engine of 772 pounds (3.4 kN) thrust
# 048: Couldn't parse speed: Not documented
# 048: Couldn't parse ceiling: Not documented
# 048: Couldn't parse range: Not documented
# 048: Couldn't parse weight: Not documented
# 048: Couldn't parse weight: Not documented
# 049: Couldn't parse dimension: 36 feet 1 inch (11.00 m)
# 051: Couldn't parse dimension: 20 feet 1 inch (6.13 m)
# 052: Couldn't parse range: 1,181 miles (1,900 km) with external fuel
# 057: Couldn't parse range: 1,000 miles (1,609 km)
# 058: Couldn't parse dimension: 27 feet 1 inch (8.25 m)
# 066: Couldn't parse range: 1,150 miles (1,850 km)
# 067: Couldn't parse range: 1,170 miles (1,883 km)
# 068: Couldn't parse range: 1,438 miles (2,315 km)
# 070: Couldn't parse range: 1,050 miles (1,690 km)
# 071: Couldn't parse range: 1,035 miles (1,666 km)
# 075: Couldn't parse range: 1,120 miles (1,802 km)
# 077: Couldn't parse range: 1,200 miles (1,931 km)
# 081: Couldn't parse range: 2,300 miles (3,700 km)
# 082: Couldn't parse dimension: 32 feet 1 inch (9.79 m)
# 083: Couldn't parse dimension: 15 feet 1 inch (4.6 m)
# 085: Couldn't parse range: 1,105 miles (1,778 km) on internal fuel tanks
# 085: Couldn't parse dimension: 40 feet 1 inch (12.22 m)
# 086: Couldn't parse range: 1,237 miles (1,990 km)
# 086: Couldn't parse dimension: 12 feet 1 inch (3.68 m)
# 087: Couldn't parse range: 1,150 miles (1,851 km) without torpedo
# 088: Couldn't parse range: 1,696 miles (2,730 km)
# 089: Couldn't parse range: 1,460 miles (2,350 km)
# 090: Couldn't parse range: 1,750 miles (2,818 km) maximum fuel
# 091: Couldn't parse range: 1,540 miles (2,478 km)
# 093: Couldn't parse range: 1,000 miles (1,609 km)
# 094: Couldn't parse speed: 202 mph (325 km/h)
# 096: Couldn't parse range: 1,275 miles (2,052 km) with 3,200 pounds of bombs
# 097: Couldn't parse range: 1,056 miles (1,700 km)
# 098: Couldn't parse range: 1,110 miles (1,786 km)
# 099: Couldn't parse range: 1,491 miles (2,400 km)
# 100: Couldn't parse powerplant: Junkers Jumo 004B-1 axial-flow turbojet engines each rated at 1,984 pounds (8.83 kN) of thrust
# 100: Couldn't parse range: 1,013 miles (1,630 km)
# 100: Couldn't parse dimension: 14 feet 1 inch (4.29 m)
# 101: Couldn't parse range: 1,400 miles (2,255 km)
# 102: Couldn't parse range: 1,860 miles (3,000 km)
# 103: Couldn't parse dimension: 59 feet 1 inch (18.00 m)
# 104: Couldn't parse range: 1,180 miles (1,900 km)
# 104: Couldn't parse dimension: 14 feet 1 inch (4.30 m)
# 105: Couldn't parse speed: 278 mph (447 km/h)
# 105: Couldn't parse range: 1,900 miles (3,058 km)
# 106: Couldn't parse range: 1,960 miles (3,155 km)
# 107: Couldn't parse speed: 226 mph (365 km/h)
# 107: Couldn't parse range: 1,700 miles (2,745 km)
# 108: Couldn't parse range: 1,885 miles (3,034 km)
# 109: Couldn't parse powerplant: Pratt & Whitney R-2800-43 Double Wasp, 18-cylinder, radial piston engines rated at 2,000 hp (1,493 kW) each
# 109: Couldn't parse range: 1,150 miles (1,851 km)
# 110: Couldn't parse dimension: 11 feet 1 inch (3.38 m)
# 111: Couldn't parse speed: 141 mph (227 km/h)
# 111: Couldn't parse dimension: 41 feet 10.5 inches (12.76 m)
# 114: Couldn't parse speed: 173 mph (278 km/h) at sea level
# 118: Couldn't parse speed: 190 mph (330 km/h) at sea level
# 118: Couldn't parse dimension: 36 feet 1 inch (11.00 m)
# 121: Couldn't parse speed: 116 mph (187 km/h)
# 124: Couldn't parse range: 1,491 miles (2,400 km)
# 126: Couldn't parse speed: 114 mph (183 km/h)
# 128: Couldn't parse speed: 85 mph (137 km/h)
# 129: Couldn't parse speed: 236 mph (380 km/h)
# 129: Couldn't parse dimension: 12 feet 1 inch (3.68 m)
# 130: Couldn't parse speed: 190 mph (306 km/h)
# 131: Couldn't parse speed: 190 mph (306 km/h)
# 133: Couldn't parse dimension: 31 feet 1 inch (9.47 m)
# 134: Couldn't parse speed: 177 mph (285 km/h)
# 134: Couldn't parse range: 3,107 miles (5,000 km)
# 135: Couldn't parse range: 2,200 miles (3,395 km)
# 135: Couldn't parse dimension: 49 feet 1 inch (14.96 m)
# 136: Couldn't parse speed: 109 mph (175 km/h) at sea level
# 137: Couldn't parse dimension: 12 feet 1 inch (3.68 m)
# 138: Couldn't parse speed: 149 mph (240 km/h)
# 138: Couldn't parse dimension: 36 feet 1 inch (11.00 m)
# 139: Couldn't parse range: 2,690 miles (4,329 km)
# 140: Couldn't parse dimension: 13 feet 1 inch (3.99 m)
# 142: Couldn't parse dimension: 37 feet 1 inch (11.30 m)
# 143: Couldn't parse powerplant: BMW VI, 12-cylinder, liquid-cooled inline piston engines 600 hp (448 kW) each
# 143: Couldn't parse speed: 143 mph (230 km/h)
# 143: Couldn't parse range: 2,230 miles (3,600 km)
# 143: Couldn't parse dimension: 19 feet 1 inch (5.82 m)
# 146: Couldn't parse speed: 90 mph (145 km/h)
# 148: Couldn't parse range: 2,300 miles (3,700 km)
# 149: Couldn't parse range: 2,520 miles (4,030 km) with full military load
# 151: Couldn't parse range: 2,082 miles (3,350 km)
# 152: Couldn't parse speed: 230 mph (370 km/h) at sea level
# 154: Couldn't parse range: 4,210 miles (6,775 km)
# 154: Couldn't parse dimension: 84 feet 1 inch (25.63 m)
# 155: Couldn't parse speed: 183 mph (295 km/h) at sea level
# 156: Couldn't parse speed: 144 mph (232 km/h) with no load, 118 mph (190 km/h) loaded with maximum cargo
# 157: Couldn't parse range: 3,150 miles (5,069 km)
# 157: Couldn't parse dimension: 108 feet 1 inch (32.94 m)
# 158: Couldn't parse range: 3,800 miles (6,115 km) with fuselage fuel tanks
# 159: Couldn't parse range: 2,000 miles (3,220 km) [special variants up to 5,500 miles (8,047 km)]
# 160: Couldn't parse speed: 330 mph (531 km/h) at sea level
# 160: Couldn't parse range: 2,290 miles (3,685 km)
# 161: Couldn't parse range: 1,335 miles (2,150 km)
# 162: Couldn't parse range: 1,833 miles (2,950 km)
# 162: Couldn't parse dimension: 54 feet 1 inch (16.50 m)
# 163: Couldn't parse range: 1,030 miles (1,658 km) with maximum bomb load
# 164: Couldn't parse range: 1,030 miles (1,658 km)
# 164: Couldn't parse dimension: 99 feet 1 inch (30.20 m)
# 165: Couldn't parse range: 2,530 miles (4,072 km)
# 166: Couldn't parse range: 1,696 miles (2,730 km) [limited by radio guidance system]
# 167: Couldn't parse range: 3,486 miles (5,610 km)
# 168: Couldn't parse speed: 133 mph (215 km/h) at sea level
# 168: Couldn't parse range: 1,367 miles (2,200 km)
# 169: Couldn't parse range: 3,417 miles (5,500 km) with two Henschel Hs 293 missiles
# 170: Couldn't parse range: 2,000 miles (3,219 km) with 6,000-pound bomb load
# 171: Couldn't parse range: 2,100 miles (3,389 km)
# 172: Couldn't parse range: 2,212 miles (3,570 km)
# 173: Couldn't parse range: 4,200 miles (6,760 km)
# 174: Couldn't parse speed: 333 mph (537 km/h)
# 174: Couldn't parse range: 2,360 miles (3,800 km)
# 175: Couldn't parse powerplant: Argus 109 014 pulse jet engine of 772 pounds (3.43 kN) of thrust
# 175: Couldn't parse weight: Not applicable
# 176: Couldn't parse powerplant: bi-fuel liquid oxygen and alcohol rocket engine
# 176: Couldn't parse speed: 3,466 mph (5,578 km/h)
# 176: Couldn't parse ceiling: 60 miles (96 km) above ground
# 176: Couldn't parse range: up to 200 miles (322 km) [variable dependent upon fuel load]
# 176: Couldn't parse weight: Not applicable
# 176: Couldn't parse dimension: 40 feet 1 inch (12.22 m)
# 177: Couldn't parse dimension: 17 feet 2 inch (5.25 m)
# 179: Couldn't parse range: 1,680 miles (2,700 km)
# 181: Couldn't parse speed: 180 mph (290 km/h)
# 181: Couldn't parse dimension: 15 feet 1 inch (4.60 m)
# 182: Couldn't parse speed: 249 mph (401 km/h)
# 182: Couldn't parse range: 1,270 miles (2,044 km)
# 183: Couldn't parse speed: 230 mph (370 km/h)
# 183: Couldn't parse dimension: 36 feet 1 inch (11.00 m)
# 183: Couldn't parse dimension: 13 feet 1 inch (3.99 m)
# 184 : Couldn't parse speed: 215 mph (344 km/h)
# 185 : Couldn't parse speed: 240 mph (386 km/h)
# 186: Couldn't parse speed: 267 mph (430 km/h)
# 186: Couldn't parse dimension: 53 feet 0.5 inches (16.17 m)
# 186: Couldn't parse dimension: 14 feet 1 inch (4.30 m)
# 187 : Couldn't parse speed: 199 mph (320 km/h)
# 188: Couldn't parse speed: 232 mph (373 km/h)
# 188: Couldn't parse range: 2,722 miles (4,380 km)
# 188: Couldn't parse dimension: 12 feet 1 inch (3.68 m)
# 189 : Couldn't parse speed: 230 mph (370 km/h)
# 190 : Couldn't parse speed: 171 mph (275 km/h)
# 190 : Couldn't parse range: 1,490 miles (2,400 km)
# 191 : Couldn't parse speed: 225 mph (346 km/h)
# 191 : Couldn't parse range: 1,200 miles (1,900 km)
# 192: Couldn't parse dimension: 10 feet 5.25 inches (4.25 m)
# 193 : Couldn't parse speed: 211 mph (240 km/h)
# 193 : Couldn't parse range: 1,200 miles (2,000 km)
# 193 : Couldn't parse dimension: 60 feet 1 inch (17.80 m)
# 194 : Couldn't parse powerplant: Junkers Jumo 9-cylinder, air-cooled radial piston engine
# 194 : Couldn't parse speed: 165 mph (265 km/h)
# 195 : Couldn't parse speed: 245 mph (394 km/h)
# 196 : Couldn't parse powerplant: Walter-built Bristol Pegasus IIM2, 9-cylinder, radial piston engine with 635 hp (473.5 kW)
# 196 : Couldn't parse speed: 174 mph (280 km/h)
# 197 : Couldn't parse range: 1,242 miles (2,000 km)
# 197 : Couldn't parse dimension: 17 feet 1 inch (5.22 m)
# 198 : Couldn't parse speed: 178 mph (285 km/h)
# 199 : Couldn't parse speed: 370 mph (595 km/h)
# 199 : Couldn't parse range: Over 1,050 miles (1,750 km)
# 199 : Couldn't parse dimension: 29 feet 1 inch (8.86 m)
# 202: Couldn't parse range: 1,890 miles (3,045 km)
# 203: Couldn't parse range: 2,722 miles (4,380 km)
# 203: Couldn't parse dimension: 12 feet 1 inch (3.69 m)
# 204: Couldn't parse range: 1,350 miles (2,168 km)
# 204: Couldn't parse dimension: 11 feet 1 inch (3.39 m)
# 206: Couldn't parse range: 2,240 miles (3,605 km)
# 207: Couldn't parse speed: 236 mph (380 km/h)
# 208: Couldn't parse range: 1,050 miles (1,690 km)
# 211: Couldn't parse range: 1,300 miles (2,092 km)
# 212: Couldn't parse speed: 127 mph (205 km/h)
# 212: Couldn't parse dimension: 35 feet 1 inch (10.70 m)
# 214: Couldn't parse speed: 130 mph (209 km/h)
# 214: Couldn't parse dimension: 24 feet 1 inch (7.34 m)
# 215: Couldn't parse speed: 195 mph (314 km/h)
# 216: Couldn't parse speed: 150 mph (241 km/h) at sea level
# 216: Couldn't parse dimension: 30 feet 1 inch (9.17 m)
# 217: Couldn't parse speed: 220 mph (354 km/h)
# 218: Couldn't parse dimension: 11 feet 1 inch (3.38 m)
# 219: Couldn't parse range: 1,210 miles (1,947 km)
# 219: Couldn't parse dimension: 53 feet 1 inch (16.18 m)
# 220: Couldn't parse speed: 267 mph (430 km/h)
# 221: Couldn't parse speed: 206 mph (331 km/h)
# 221: Couldn't parse range: 2,920 miles (4,700 km)
# 221: Couldn't parse weight: 40.515 pounds (18,400 kg)
# 224: Couldn't parse range: 4,443 miles (7,150 km)
# 226: Couldn't parse speed: 111 mph (178 km/h)
# 228: Couldn't parse powerplant: 9-cylinder air-cooled radial piston engine
# 228: Couldn't parse speed: Not documented
# 228: Couldn't parse ceiling: Not documented
# 228: Couldn't parse range: Not documented
# 228: Couldn't parse weight: Not documented
# 228: Couldn't parse weight: Not documented
# 228: Couldn't parse dimension: 12 feet 1 inch (3.68 m)
# 229: Couldn't parse range: 1,218 miles (1,960 km)
# 230: Couldn't parse range: 1,025 miles (1,650 km)
# 230: Couldn't parse dimension: 40 feet 1 inch (12.22 m)
# 231: Couldn't parse dimension: 13 feet 1 inch (3.99 m)
# 232: Couldn't parse speed: 162 mph (260 km/h)
# 232: Couldn't parse range: 2,174 miles (3,500 km)
# 233: Couldn't parse range: 1,300 miles (2.092 km)
# 234: Couldn't parse speed: 391 mph (630 km/h)
# 235: Couldn't parse dimension: 36 feet 1 inch (11.00 m)
# 236: Couldn't parse range: 1,137 miles (1,830 km)
# 236: Couldn't parse dimension: 15 feet 1 inch (4.59 m)
# 237: Couldn't parse speed: 110 mph (177 km/h)
# 237: Couldn't parse dimension: 37 feet (11.28 m)
# 239: Couldn't parse dimension: 36 feet 1 inch (11.00 m)
# 240: Couldn't parse range: 1,135 miles (1,827 km)
# 241: Couldn't parse powerplant: Heinkel He.S 011 axial flow turbojet engine with 3,500 pounds (15.6 kN) of thrust
# 241: Couldn't parse speed: 596 mph (955 km/h)
# 242: Couldn't parse speed: 177 mph (285 km/h)
# 242: Couldn't parse range: 1,710 miles (2,750 km)
# 245: Couldn't parse speed: 205 mph (330 km/h) at sea level
# 245: Couldn't parse dimension: 36 feet 1 inch (11.00 m)
# 246: Couldn't parse range: 1,300 miles (2,090 km)
# 246: Couldn't parse dimension: 37 feet 1 inch (11.30 m)
# 247: Couldn't parse speed: 150 mph (241 km/h) at sea level
# 247: Couldn't parse dimension: 12 feet 1 inch (3.68 m)
# 248: Couldn't parse speed: 180 mph (290 km/h) at sea level
# 248: Couldn't parse ceiling: 21.650 feet (6,600 m)
# 249: Couldn't parse speed: 134 mph (216 km/h) at sea level
# 251: Couldn't parse speed: 153 mph (246 km/h)
# 251: Couldn't parse dimension: 36 feet 1 inch (11.00 m)
# 252: Couldn't parse speed: 416 mph (670 km/h)
# 253: Couldn't parse range: 2,476 miles (3,985 km)
# 253: Couldn't parse dimension: 14 feet 1 inch (4.3 m)
# 254: Couldn't parse range: 1,460 miles (2,350 km)
# 254: Couldn't parse weight: Not documented
# 255: Couldn't parse speed: 222 mph (357 km/h)
# 255: Couldn't parse range: 1,080 miles (1,738 km)
# 256: Couldn't parse range: 1,430 miles (2,300 km)
# 257: Couldn't parse speed: 149 mph (240 km/h) at sea level
# 260: Couldn't parse speed: 106 mph (170 km/h)
# 260: Couldn't parse weight: Not available
# 262: Couldn't parse speed: 155 mph (250 km/h)
# 263: Couldn't parse speed: 223 mph (360 km/h)
# 264: Couldn't parse speed: 168 mph (270 km/h)
# 265: Couldn't parse speed: 416 mph (670 km/h)
# 265: Couldn't parse dimension: 26 feet 1 inch (7.95 m)
# 266: Couldn't parse speed: 137 mph (220 km/h)
# 267 : Couldn't parse speed: 174 mph (280 km/h)
# 267 : Couldn't parse dimension: 11 feet 1 inch (3.38 m)
# 268: Couldn't parse speed: 264 mph (425 km/h)
# 268: Couldn't parse range: 2,485 miles (4,000 km)
# 269: Couldn't parse speed: 302 mph (486 km/h)
# 270: Couldn't parse speed: 409 mph (658 km/h)
# 271: Couldn't parse speed: 230 mph (370 km/h)
# 272: Couldn't parse speed: 172 mph (277 km/h)
# 272: Couldn't parse range: 330 to 621 miles (530 to 1,000 km)
# 272: Couldn't parse dimension: 36 feet 1 inch (11.0 m)
# 273: Couldn't parse speed: 246 mph (396 km/h)
# 273: Couldn't parse dimension: 46 feet 4.5 inches (14.14 m)
# 274: Couldn't parse speed: 276 mph (445 km/h)
# 274: Couldn't parse range: 2,360 miles (3,800 km)
# 275: Couldn't parse speed: 122 mph (196 km/h)
# 276: Couldn't parse powerplant: 540 hp (400 kW) Hispano-Suiza or one 480 hp (358 kW) Rolls Royce Kestrel IIS, both 12-cylinder, liquid-cooled inline piston engines
# 276: Couldn't parse weight: Not available
# 276: Couldn't parse dimension: 31 feet 1 inch (9.47 m)
# 277: Couldn't parse speed: 137 mph (220 km/h)
# 277: Couldn't parse range: 1,087 miles (1,750 km)
# 277: Couldn't parse dimension: 57 feet 1 inch (17.40 m)
# 277: Couldn't parse dimension: 23 feet 3.5 inches (7.10 m)
# 278: Couldn't parse powerplant: Three Wright J-5 Whirlwind radial engines with 300 hp (224 kW) each
# 278: Couldn't parse speed: 129 mph (207 km/h)
# 278: Couldn't parse ceiling: Not Documented
# 278: Couldn't parse range: Non-stop across the Atlantic
# 279 : Couldn't parse powerplant: Lycoming R-680-9 air-cooled radial piston engine with 295 hp (220 kW)
# 279 : Couldn't parse speed: 122 mph (196 km/h)
# 280: Couldn't parse range: 1,107 miles (1,782 km)
# 280: Couldn't parse dimension: 14 feet 1 inch (4.3 m)
# 281: Couldn't parse speed: 201 mph (327 km/h)
# 281: Couldn't parse range: 4,410 miles (7,100 km)
# 283: Couldn't parse speed: 180 mph (290 km/h) at sea level
# 284: Couldn't parse speed: 165 mph (266 km/h)
# 284: Couldn't parse dimension: 31 feet 1 inch (9.47 m)
# 287: Couldn't parse range: 1,240 miles (1,996 km)
# 287: Couldn't parse weight: 9.681 pounds (4,391 kg)
# 290: Couldn't parse speed: 304 mph (430 km/h)
# 290: Couldn't parse range: 1,019 miles (1,640 km)
# 291: Couldn't parse speed: 160 mph (257 km/h) at sea level
# 292: Couldn't parse range: 1,860 miles (2,995 km)
# 293: Couldn't parse range: 3,500 miles (5,633 km)
# 294: Couldn't parse speed: 110 mph (177 km/h)
# 295: Couldn't parse range: 2,390 miles (3,846 km)
# 296: Couldn't parse speed: 124 mph (200 km/h)
# 297: Couldn't parse range: 1,360 miles (2,189 km)
# 298: Couldn't parse powerplant: None
# 298: Couldn't parse speed: Maximum towing speed 150 mph (241 km/h), normal towing speed 100 mph (161 km/h)
# 298: Couldn't parse ceiling: Usually below 8,000 feet (2,438 m)
# 298: Couldn't parse range: Dependent upon towing aircraft
# 299: Couldn't parse range: 2,159 miles (3,475 km) with auxiliary fuel
# 300: Couldn't parse speed: 102 mph (164 km/h)
# 301: Couldn't parse powerplant: None. C-47s and C-46s were commonly used as tugs.
# 301: Couldn't parse speed: Up to 140 mph (225 km/h) when towed by their tugs
# 301: Couldn't parse ceiling: Below 10,000 feet (3,048 m)
# 301: Couldn't parse range: Dependent on operation, rarely beyond 350 miles (563 km)
# 302: Couldn't parse speed: 197 mph (317 km/h)
# 303: Couldn't parse speed: 242 mph (391 km/h)
# 303: Couldn't parse range: 3,787 miles (6,095 km)
# 304: Couldn't parse speed: 273 mph (440 km/h)
# 304: Couldn't parse range: 3,821 miles (6,150 km)
# 305: Couldn't parse speed: 109 mph (175 km/h)
# 305: Couldn't parse crew: Usually crew of 2 and up to 6 passengers
# 306: Couldn't parse powerplant: Hitachi Ha 13a 9-cylinder, air-cooled radial piston engine with 510 hp (380 kW)
# 306: Couldn't parse speed: 216 mph (348 km/h)
# 306: Couldn't parse dimension: 38 feet 8.5 inches (11.80 m)
# 307: Couldn't parse speed: 270 mph (435 km/h), 140 mph (225 km/h) pulling Me 321
# 307: Couldn't parse range: 1,243 miles (2,000 km), 960 miles (1,545 km) pulling Me 321
# 308: Couldn't parse powerplant: Eight Walter 109-500 hydrogen peroxide rockets [four under each wing], each providing 1,102 pounds (4.9 kN) of thrust for 30 seconds
# 308: Couldn't parse speed: 140 mph (225 km/h) when towed by He 111 Z tug
# 308: Couldn't parse range: Up to 600 miles (965 km) when towed by He 111 Z tug
# 309: Couldn't parse speed: 138 mph (222 km/h)
# 309: Couldn't parse range: 1,030 miles (1,658 km)
# 310: Couldn't parse speed: 230 mph (370 km/h)
# 310: Couldn't parse range: 1,600 miles (2,575 km)
# 311: Couldn't parse speed: 105 mph (169 km/h)
# 312: Couldn't parse speed: 298 mph (479 km/h)
# 312: Couldn't parse range: 2,700 miles (4,345 km)
# 313: Couldn't parse speed: 397 mph (639 km/h)
# 313: Couldn't parse range: More than 3,000 miles (4,830 km)
# 313: Couldn't parse dimension: 36 feet 1 inch (11.00 m)
# 314: Couldn't parse speed: 220 mph (354 km/h)
# 314: Couldn't parse range: 1,195 miles (1,923 km) without bombs
# 315: Couldn't parse speed: 435 mph (700 km/h)
# 315: Couldn't parse range: 1,200 miles (1,931 km)
# 316: Couldn't parse speed: 360 mph (580 km/h)
# 316: Couldn't parse range: 1,242 miles (2,000 km)
# 316: Couldn't parse dimension: 51 feet 1 inch (15.57 m)
# 317: Couldn't parse speed: 288 mph (463 km/h)
# 318: Couldn't parse speed: 286 mph (460 km/h)
# 318: Couldn't parse range: 1,305 miles (2,100 km)
# 319: Couldn't parse speed: 306 mph (492 km/h)
# 319: Couldn't parse range: 1,500 miles (2,414 km)
# 320: Couldn't parse speed: 211 mph (340 km/h)
# 320: Couldn't parse crew: Flight crew of 5 or 6
# 321: Couldn't parse speed: 121 mph (195 km/h) at sea level
# 322: Couldn't parse speed: 126 mph (203 km/h)
# 324: Couldn't parse speed: 180 mph (290 km/h)
# 325: Couldn't parse speed: 190 mph (306 km/h)
# 326: Couldn't parse speed: 196 mph (315 km/h)
# 326: Couldn't parse range: 3,293 miles (5,300 km)
# 330: Couldn't parse range: 1,000 miles (1,609 km)
# 331: Couldn't parse speed: 132 mph (212 km/h) at sea level
# 331: Missing weight
# 333: Couldn't parse speed: 137 mph (220 km/h) at sea level
# 334: Couldn't parse speed: 114 mph (220 km/h) at sea level
# 336: Couldn't parse range: 1,118 miles (1,800 km)
# 339: Couldn't parse range: 1,300 miles (2,092 km)
# 340: Couldn't parse range: 1,209 miles (1,945 km)
# 340: Couldn't parse dimension: 35 feet 1 inch (10.70 m)
# 341: Couldn't parse speed: 109 mph (175 km/h)
# 342: Couldn't parse speed: 115 mph (185 km/h)
# 342: Couldn't parse dimension: 34 feet 1 inch (10.40 m)
# 346: Couldn't parse speed: 118 mph (200 km/h)
# 347: Couldn't parse speed: 109 mph (175 km/h)
# 347: Couldn't parse dimension: 6 feet 1 inch (1.85 m)
# 348: Couldn't parse range: 1,130 miles (1,820 km)
# 349: Couldn't parse range: 1,242 miles (2,000 km)
# 352: Couldn't parse speed: 326 mph (525 km/h)
# 354: Couldn't parse speed: 208 mph (335 km/h)
# 355: Couldn't parse dimension: 36 feet 1 inch (11.00 m)
# 356: Couldn't parse range: 4,660 miles (7,500 km) [Projected]
# 357: Couldn't parse range: 1,036 miles (1,667 km)
# 359: Couldn't parse dimension: 33 feet 1 inch (11.64 m)
# 360: Couldn't parse dimension: 13 feet 1 inch (4.00 m)
# 361: Couldn't parse speed: 267 mph (430 km/h)
# 361: Couldn't parse range: 2,175 miles (3,500 km)
# 362: Couldn't parse speed: 250 mph (402 km/h)
# 363: Couldn't parse speed: 202 mph (325 km/h)
# 364: Couldn't parse speed: 291 mph (468 km/h) [with center float attached]
# 364: Couldn't parse range: 2,095 miles (3,372 km)
# 364: Couldn't parse dimension: 46 feet 1 inch (14.05 m)
# 364: Couldn't parse dimension: 36 feet 1 inch (11.00 m)
# 365 : Couldn't parse speed: 248 mph (400 km/h)
# 365 : Couldn't parse dimension: 32 feet 10.5 inches (10.02 m)
# 366 : Couldn't parse speed: 265 mph (426 km/h)
# 366 : Couldn't parse range: 1,630 miles (2,623 km)
# 366 : Couldn't parse dimension: 90 feet 1 inch (27.46 m)
# 367: Couldn't parse speed: 286 mph (460 km/h)
# 369: Couldn't parse powerplant: None
# 369: Couldn't parse speed: 20 mph (32 km/h) [limited by the speed of the Type IX submarine]
# 369: Couldn't parse range: Determined by the submarine
# 369: Couldn't parse weight: Not applicable
# 371: Couldn't parse speed: 335 mph (539 km/h)
# 371: Couldn't parse range: 1,056 miles (1,700 km)
# 372: Couldn't parse speed: 422 mph (679 km/h)
# 372: Couldn't parse dimension: 32 feet 1 inch (10.69 m)
# 372: Couldn't parse dimension: 10 feet 1 inch (3.07 m)
# 373: Couldn't parse dimension: 29 feet 1 inch (8.85 m)
# 374: Couldn't parse speed: 133 mph (214 km/h)
# 375: Couldn't parse speed: 298 mph (480 km/h)
# 375: Couldn't parse range: 1,535 miles (3,500 km) without bombs
# 377 : Couldn't parse range: 1,130 miles (1,818 km)
# 378 : Couldn't parse powerplant: Ram Jet engines and one rocket engine [thrust not available]
# 378 : Couldn't parse speed: 699 mph [Mach 1.05] at 32,800 feet (1,125 km/h at 10,000 m) [proposed]
# 378 : Couldn't parse ceiling: Over 35,000 feet (10,700 m) [proposed]
# 378 : Couldn't parse range: Not available
# 378 : Couldn't parse weight: Not available
# 378 : Couldn't parse dimension: 25 feet 1 inch (7.65 m)
# 379 : Couldn't parse powerplant: He S 011A turbojet engines, one Walter rocket engine, all mounted in fuselage
# 379 : Couldn't parse speed: 516 mph (830 km/h) [proposed]
# 379 : Couldn't parse weight: Not available
# 379 : Couldn't parse weight: Not available
# 380 : Couldn't parse speed: 223 mph (359 km/h)
# 380 : Couldn't parse range: 2,370 miles (3,814 km)
# 382: Couldn't parse range: 2,348 miles (3,780 km)
# 382: Couldn't parse dimension: 13 feet 1 inch (3.99 m)
# 383: Couldn't parse speed: 233 mph (375 km/h) at sea level
# 383: Couldn't parse range: 2,423 miles (3,900 km)
# 383: Couldn't parse dimension: 67 feet 1 inch (20.45 m)
# 385: Couldn't parse powerplant: Four BMW 003A 1,764-pound (7.8-kN) thrust turbojet engines
# 385: Couldn't parse dimension: 14 feet 1 inch (4.30 m)
# 386: Couldn't parse range: 1,537 miles (2,474 km)
# 386: Couldn't parse dimension: 36 feet 1 inch (11.00 m)
# 387: Couldn't parse speed: 301 mph (484 km/h) at sea level
# 388: Couldn't parse powerplant: Junkers Jumo jet engines in the development stage that were projected to have much more thrust than the Junkers Jumo 004Bs of the Me 262
# 388: Couldn't parse speed: 650 mph (1,046 km/h) [projected]
# 388: Couldn't parse weight: Not documented
# 388: Couldn't parse weight: Not documented
# 388: Couldn't parse dimension: 11 feet 1 inch (3.36 m)
# 389: Couldn't parse range: 1,914 miles (3,080 km)
# 390: Couldn't parse speed: 185 mph (298 km/h)
# 391: Couldn't parse range: 1,429 miles (2,300 km)
# 392: Couldn't parse speed: 327 mph (527 km/h)
# 394: Couldn't parse speed: 202 mph (325 km/h)
# 394: Couldn't parse range: 1,025 miles (1,650 km)
# 396: Couldn't parse speed: 115 mph (186 km/h)
# 397: Couldn't parse speed: 165 mph (266 km/h)
# 397: Couldn't parse weight: Not documented
# 397: Couldn't parse weight: Not documented
# 398: Couldn't parse range: 1,367 miles (2,200 km)
# 398: Couldn't parse dimension: 118 feet 1 inch (36.00 m)
# 398: Couldn't parse dimension: 17 feet 1 inch (5.20 m)
# 399: Couldn't parse range: 2,480 miles (4,000 km)
# 399: Couldn't parse dimension: 36 feet 1 inch (11.00 m)
# 400: Couldn't parse dimension: 36 feet 1 inch (11.00 m)
# 401: Couldn't parse powerplant: Three type 4 Mk 1 Model 20 solid propellant rockets with total thrust of 1,766 pounds (7.8 kN)
# 401: Couldn't parse speed: 404 mph (650 km/h)
# 401: Couldn't parse ceiling: Not available
# 402: Couldn't parse speed: 168 mph (270 km/h)
# 403: Couldn't parse range: 1,888 miles (3,040 km)
# 404: Couldn't parse speed: 128 mph (206 km/h)
# 404: Couldn't parse dimension: 23 feet 1 inch (7.03 m)
# 407: Couldn't parse range: 3,050 miles (4,908 km)
# 408: Couldn't parse speed: 295 mph 17,000 feet (475 km/h at 5,200 m)
# 409: Couldn't parse ceiling: 20.890 feet (6,367 m)
# 410: Couldn't parse range: 1,105 miles (1,778 km)
# 411: Couldn't parse speed: 177 mph (284 km/h)
# 412: Couldn't parse range: 1,504 miles (2,420 km)
# 413: Couldn't parse range: 1,213 miles (1,953 km)
# 413: Couldn't parse dimension: 15 feet 1 inch (4.60 m)
# 418: Couldn't parse dimension: 44 feet 1 inch (13.44 m)
# 421: Couldn't parse speed: 270 mph (435 km/h) at sea level
# 421: Couldn't parse dimension: 38 feet 1 inch (11.60 m)
# 423: Couldn't parse range: 1,300 miles (3,092 km)
# 424: Couldn't parse speed: 155 mph (249 km/h)
# 424: Couldn't parse range: 1,150 miles (1,890 km)
# 425: Couldn't parse range: 1,379 miles (3,120 km)
# 426: Couldn't parse range: Up to 2,230 miles (3,589 km) fitted with extra fuel tanks
